# %% [markdown]
# ### Create a table from latex to excel

# %%
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")

# %%
# Create a dictionary with your data
data = {
    'Model': ['Top75Pr', 'Top50Pr', 'Top25Pr', 'Top10Pr', 'average'],
    'LSTM (Efficiency Gains)': [2.61, 2.38, 0.97, -0.84, 1.28],
    'DTW (Efficiency Gains)': [2.28, 2.58, 3.23, 3.20, 2.82],
    'KNN (Efficiency Gains)': [0.50, 0.98, 1.58, 2.13, 1.3],
    'HMM (Efficiency Gains)': [9.31, 7.34, 1.30, 6.05, 6.0],
    'LSTM (Counts of Improved Voyages)': [134, 129, 100, 60, 105.75],
    'DTW (Counts of Improved Voyages)': [119, 117, 128, 127, 122.75],
    'KNN (Counts of Improved Voyages)': [93, 106, 107, 114, 105],
    'HMM (Counts of Improved Voyages)': [141, 140, 107, 139, 131.75]
}

# Create a DataFrame from the data
df = pd.DataFrame(data)


# Create a DataFrame from the updated data
df = pd.DataFrame(data)

# # Write the DataFrame to an Excel file
# df.to_excel('Table_gains_counts.xlsx', index=False)

# %%
df
# Out:
#      Model  LSTM (Efficiency Gains)  DTW (Efficiency Gains)  \
# 0  Top75Pr                     2.61                    2.28
# 1  Top50Pr                     2.38                    2.58
# 2  Top25Pr                     0.97                    3.23
# 3  Top10Pr                    -0.84                    3.20
# 4  average                     1.28                    2.82
#
#    KNN (Efficiency Gains)  HMM (Efficiency Gains)  \
# 0                    0.50                    9.31
# 1                    0.98                    7.34
# 2                    1.58                    1.30
# 3                    2.13                    6.05
# 4                    1.30                    6.00
#
#    LSTM (Counts of Improved Voyages)  DTW (Counts of Improved Voyages)  \
# 0                             134.00                            119.00
# 1                             129.00                            117.00
# 2                             100.00                            128.00
# ...

# %%
df_statistics = df.iloc[:-1].describe()
df_statistics
# Out:
#        LSTM (Efficiency Gains)  DTW (Efficiency Gains)  \
# count                 4.000000                4.000000
# mean                  1.280000                2.822500
# std                   1.588437                0.469636
# min                  -0.840000                2.280000
# 25%                   0.517500                2.505000
# 50%                   1.675000                2.890000
# 75%                   2.437500                3.207500
# max                   2.610000                3.230000
#
#        KNN (Efficiency Gains)  HMM (Efficiency Gains)  \
# count                4.000000                 4.00000
# mean                 1.297500                 6.00000
# std                  0.709384                 3.40804
# min                  0.500000                 1.30000
# 25%                  0.860000                 4.86250
# 50%                  1.280000                 6.69500
# 75%                  1.717500                 7.83250
# ...

# %%
df.iloc[:-1]
# Out:
#      Model  LSTM (Efficiency Gains)  DTW (Efficiency Gains)  \
# 0  Top75Pr                     2.61                    2.28
# 1  Top50Pr                     2.38                    2.58
# 2  Top25Pr                     0.97                    3.23
# 3  Top10Pr                    -0.84                    3.20
#
#    KNN (Efficiency Gains)  HMM (Efficiency Gains)  \
# 0                    0.50                    9.31
# 1                    0.98                    7.34
# 2                    1.58                    1.30
# 3                    2.13                    6.05
#
#    LSTM (Counts of Improved Voyages)  DTW (Counts of Improved Voyages)  \
# 0                              134.0                             119.0
# 1                              129.0                             117.0
# 2                              100.0                             128.0
# 3                               60.0                             127.0
#
# ...

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.8.0

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.8.0

# %%
import keras
print(keras.__version__)
# Out:
# 2.8.0

# %%
### Python
import sys
sys.version
# Out:
# '3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]'
